# %% [markdown]
# # Identifying customer segments via RFM k-means clustering
# ## 1. Introduction
# This analysis aims at segmenting a customer base of a UK-based online retailer by employing RFM-based k-means clustering. The utilized datset is available at http://archive.ics.uci.edu/ml/datasets/Online+Retail+II as an .xlsx file and is required to execute the analysis.
# This notebook is structured as follows: Section 2 introduces the dataset and performs a couple of exploratory analyses; Section 3 introduces the RFM terminology and deals with cleaning the data; Section 4 incldues the k-means clustering; Section 5 further segments the clusters using a random forest; Section 6 concludes.

# %% [markdown]
# ## 2. Introduction to the Dataset and exploratory analyses

# %%
# importing standard libraries required for the rest of the notebook. 
# Collecting all required libraries in one cell/ file is common practice in other coding languages and is therefore performed here
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import seaborn as sns
import datetime
from datetime import timedelta
from sklearn.cluster import KMeans
from sklearn.preprocessing import RobustScaler,StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %% [markdown]
# After loading the dataset and looking at the structure of the set, several observations can be made that are relevant for the analyses that will be performed later: Customers are idetified using a unqiue customer ID while every row represents a distinct purchase of a product at a specific date. Multiple purchases might be associated with one invoice which are distinguished by a unique Invoice ID.

# %%
df = pd.read_excel("online_retail_II.xlsx")
df.head(20)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6   489434     21871                  SAVE THE PLANET MUG        24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8   489435     22350                            CAT BOWL         12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN        12
# 10  489435     22195         HEART MEASURING SPOONS LARGE        24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# 13  489436     21755             LOVE BUILDING BLOCK WORD        18
# 14  489436     21754             HOME BUILDING BLOCK WORD         3
# 15  489436     84879        ASSORTED COLOUR BIRD ORNAMENT        16
# 16  489436     22119           PEACE WOODEN BLOCK LETTERS         3
# 17  489436     22142         CHRISTMAS CRAFT WHITE FAIRY         12
# 18  489436     22296            HEART IVORY TRELLIS LARGE        12
# 19  489436     22295            HEART FILIGREE DOVE LARGE        12
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# 5  2009-12-01 07:45:00   1.65      13085.0  United Kingdom
# 6  2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# 7  2009-12-01 07:45:00   5.95      13085.0  United Kingdom
# 8  2009-12-01 07:46:00   2.55      13085.0  United Kingdom
# 9  2009-12-01 07:46:00   3.75      13085.0  United Kingdom
# 10 2009-12-01 07:46:00   1.65      13085.0  United Kingdom
# 11 2009-12-01 07:46:00   2.55      13085.0  United Kingdom
# 12 2009-12-01 09:06:00   5.95      13078.0  United Kingdom
# 13 2009-12-01 09:06:00   5.45      13078.0  United Kingdom
# 14 2009-12-01 09:06:00   5.95      13078.0  United Kingdom
# 15 2009-12-01 09:06:00   1.69      13078.0  United Kingdom
# 16 2009-12-01 09:06:00   6.95      13078.0  United Kingdom
# 17 2009-12-01 09:06:00   1.45      13078.0  United Kingdom
# 18 2009-12-01 09:06:00   1.65      13078.0  United Kingdom
# 19 2009-12-01 09:06:00   1.65      13078.0  United Kingdom

# %% [markdown]
# We perform a couple of exploratory analyses to better understand the structure and quality of the dataset in order to prepare the set for future analyses.

# %%
# Understanding the strucutre of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
# Looking at value distribution in the dataset
df.describe()
# Out:
#             Quantity          Price    Customer ID
# count  525461.000000  525461.000000  417534.000000
# mean       10.337667       4.688834   15360.645478
# std       107.424110     146.126914    1680.811316
# min     -9600.000000  -53594.360000   12346.000000
# 25%         1.000000       1.250000   13983.000000
# 50%         3.000000       2.100000   15311.000000
# 75%        10.000000       4.210000   16799.000000
# max     19152.000000   25111.090000   18287.000000

# %%
# counting unique values in the data
df.nunique()
# Out:
# Invoice        28816
# StockCode       4632
# Description     4681
# Quantity         825
# InvoiceDate    25296
# Price           1606
# Customer ID     4383
# Country           40
# dtype: int64

# %%
# digging deeper into the origin of the customers to understand the distribution of the customers
countries = df.groupby('Country')
countries.nunique()
# Out:
#                       Invoice  StockCode  Description  Quantity  InvoiceDate  \
# Country
# Australia                  50        420          453        44           50
# Austria                    32        363          379        31           32
# Bahrain                     8         93           93        12            8
# Belgium                    65        481          521        31           65
# Bermuda                     1         34           34         9            1
# Brazil                      1         61           60         9            1
# Canada                      2         77           77        10            2
# Channel Islands            47        544          573        42           47
# Cyprus                     25        417          425        30           25
# Denmark                    33        285          294        81           33
# EIRE                      457       2054         2220       100          453
# Finland                    20        226          237        20           20
# France                    297       1301         1428       154          296
# Germany                   513       1461         1616        70          512
# Greece                     15        419          428        22           15
# Hong Kong                   6         60           61        16            6
# Iceland                     2         70           70        10            2
# Israel                      2         73           74        12            2
# Italy                      39        514          540        28           39
# Japan                      30        137          138        33           29
# Korea                       3         52           52        18            3
# Lebanon                     2         13           13         8            2
# Lithuania                   6        113          115        14            6
# Malta                       6        162          162        14            5
# Netherlands               150        881          940        81          150
# Nigeria                     3         32           32         6            3
# Norway                     15        219          223        32           15
# Poland                     15        133          136        23           16
# Portugal                   57        544          590        40           57
# RSA                         4        101          108        19            4
# Singapore                   4        110          110        21            4
# Spain                      85        683          703        45           85
# Sweden                     83        433          451        50           81
# Switzerland                50        674          719        44           48
# Thailand                    2         76           76        15            2
# USA                        18        159          165        26           18
# United Arab Emirates       19        334          336        33           19
# United Kingdom          26633       4631         4657       761        23474
# Unspecified                15        247          247        20           15
# West Indies                 1         49           49        16            1
#
#                       Price  Customer ID
# Country
# Australia                49           15
# Austria                  36           10
# Bahrain                  23            2
# Belgium                  55           17
# Bermuda                  13            0
# Brazil                   19            1
# Canada                   20            1
# Channel Islands          54           12
# Cyprus                   48            7
# Denmark                  49            9
# EIRE                    138            5
# Finland                  32            8
# France                   84           47
# Germany                  92           68
# Greece                   47            4
# Hong Kong                19            0
# Iceland                  21            1
# Israel                   22            2
# Italy                    55           11
# Japan                    29            6
# Korea                    18            2
# Lebanon                   7            0
# Lithuania                24            1
# Malta                    28            1
# Netherlands              75           23
# Nigeria                  15            1
# Norway                   38            5
# Poland                   27            2
# Portugal                 56           18
# RSA                      24            1
# Singapore                25            1
# Spain                    66           25
# Sweden                   54           16
# Switzerland              61           14
# Thailand                 21            1
# USA                      34            6
# United Arab Emirates     37            4
# United Kingdom         1494         4035
# Unspecified              35            5
# West Indies              15            1

# %% [markdown]
# Looking at the descriptive analysis of the data, there are several observations that are relevant for cleaning the data. Those are, chronologically according to the cells above:
# 1. it seems like there are records where the price and/ or quantities are below 0. In the context of an online retailer, those transactions most likely represent returns or erroneous transactions. Therefore, we proceed to filter those values out of the dataset as the first step to cleaning the data.
# 2. There are 40 countries present in the dataset, however, the UK clearly dominates the dataset with 4035 unique customers against a max. of 68 from other countries. Therefore, we propose to restrict filter out all transactions of customers not located in the UK to ensure a sufficient sample size.
# 3. We also introduce a new column, 'total_amount', that captures the basket value of the transaction which is of primary interest to us in the proceeding analyses.

# %%
# introducing an additional column
df['total_amount'] = df.Price * df.Quantity
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  total_amount
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom          83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom          81.0
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom          81.0
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom         100.8
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom          30.0

# %%
#Filtering all values which have missing values, represent returns, or are of customers that are not located in the UK.
df.dropna()
df.drop(df[df.total_amount <= 0].index, inplace=True)
df.drop(df[df.Quantity <= 0].index, inplace=True)
df.drop(df[df.Country != "United Kingdom"].index, inplace = True)

# %%
df.nunique()
# Out:
# Invoice         19291
# StockCode        4241
# Description      4510
# Quantity          370
# InvoiceDate     18015
# Price            1262
# Customer ID      3969
# Country             1
# total_amount     4265
# dtype: int64

# %% [markdown]
# ## 3. Introducing the RFM methodology & further pre-processing of the data

# %% [markdown]
# The RFM methodology classifies every customer along three dimensions: Recency, Frequency, and Monetary. Those values can then be used to segment customers into relevant segments.
# - *Recency*: Recency is defined as the recency of the last purchase from a defined cut-off date, here the last date available in the dataset. Customers with more recent purchases are likely more attractive as they either represent new or returning customers
# - *Frequency*: Frequency is defined as the number of unique purchases that the customers made in the examined timeframe. Customers with a higher frequency tend to be more promising as they shop for a variety of products via the website.
# - *Monetary*: Monetary is defined as the total value of purchases made by a customer over the examined timeframe. Customers with a higher monetary value of their purchases are the most profitable ones for the company.
#
# Although this classification has serious drawbacks in practice and greatly simplifies a customer segmentation, it lends itself well to this dataset and still represents one of the longest established methodologies for customer segmentation, especially in the retail space.

# %% [markdown]
# We proceed to pre-process the data to gegenrate a target dataset with RFM values for all customers in the cleaned dataset.

# %%
# Grouping the dataset on customer ID and calculating values for Recency, Frequency, and Monetary
# the cutoff date is defined as the last date in the 
dataset_cutoff_date = df['InvoiceDate'].max() + timedelta(days=1)
rfm = df.groupby(['Customer ID']).agg({
        'InvoiceDate': lambda x: (dataset_cutoff_date - x.max()).days,
        #'Invoice': 'count',
        'Invoice': lambda x: x.nunique(),
        'total_amount': 'sum'})

# %%
rfm.describe()
# Out:
#        InvoiceDate      Invoice   total_amount
# count  3969.000000  3969.000000    3969.000000
# mean     91.094986     4.437390    1868.167287
# std      97.071763     7.531933    7380.830030
# min       1.000000     1.000000       2.950000
# 25%      18.000000     1.000000     304.200000
# 50%      52.000000     2.000000     669.910000
# 75%     136.000000     5.000000    1655.640000
# max     374.000000   155.000000  349164.350000

# %%
# Renaming the columns to accurately depict the used RFM methodology
rfm.rename(columns={'InvoiceDate': 'Recency',
                         'Invoice': 'Frequency',
                         'total_amount': 'Monetary'}, inplace=True)
rfm.describe()
# Out:
#            Recency    Frequency       Monetary
# count  3969.000000  3969.000000    3969.000000
# mean     91.094986     4.437390    1868.167287
# std      97.071763     7.531933    7380.830030
# min       1.000000     1.000000       2.950000
# 25%      18.000000     1.000000     304.200000
# 50%      52.000000     2.000000     669.910000
# 75%     136.000000     5.000000    1655.640000
# max     374.000000   155.000000  349164.350000

# %%
# Visually exploring the distribution of values in the dataset
sns.pairplot(rfm, kind='scatter')

# %% [markdown]
# We can see that the dataset includes a couple of extreme outliers. Since we want to emply a k-means classfication on the dataset, we exlude those outliers from the set as to not skew the generated clusters.

# %%
# We exclude all values that are more than three standard deviations from the mean of the column
rfm = rfm[rfm.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %%
rfm.describe()
# Out:
#            Recency    Frequency      Monetary
# count  3913.000000  3913.000000   3913.000000
# mean     92.220802     3.804498   1375.789269
# std      97.256385     3.900128   2052.331444
# min       1.000000     1.000000      2.950000
# 25%      19.000000     1.000000    300.380000
# 50%      53.000000     2.000000    654.320000
# 75%     138.000000     5.000000   1591.240000
# max     374.000000    27.000000  23712.310000

# %% [markdown]
# Removing the outliers reduced the number of observations by 56,  from 3969 to 3913. We now procede to introduce the k-means classfication on this dataset.

# %% [markdown]
# ## 4. Generating customer clusters using k-means
#
# K-means is a popular but not very sophisticated unsupervised ML-algorithm that is often used to generate customer segments. However, given its limitations, namely the high impact of outliers and the pre-selection of the number of clusters, we perform two steps before generating clusters:
# 1. *Normalization*: To make data comparable and reduce skewing of results through outliers in the data, we normalize the RFM columns. Given the distribution & different scaling of the data in the three columns, we normalize the data using robust scaling.
# 2. *Determining optimal k*: The k-means algorithm takes a pre-defined number of clusters which, inherently, produces the risk of choosing a suboptimal number of k. To reduce that probability, we try to determine the optimal number of k using multiple approaches, namely the elbow method, the silhouette score, and the Davis Bouldin score. Functionality of those three methods is introduced below.
# 3. *Generating clusters*: Using the observed optimal number of k, we run the k-means algorithm on the data and geenrate k customer segments. We then proceed to place the results in a business context in the conclusion.

# %% [markdown]
# ### 4.1 Normalization

# %%
# Scaling with Robust Scaler
rfm_model = rfm[['Recency','Frequency','Monetary']]
standar = RobustScaler()
standar.fit(rfm_model)
rfm_model = standar.transform(rfm_model)
rfm_model = pd.DataFrame(rfm_model, columns=['Recency','Frequency','Monetary'])
rfm_model['Customer Id'] = rfm.index
# X_scaled will be used to generate the clusters and features only the target columns
X_scaled = rfm_model[['Recency','Frequency','Monetary']]
X_scaled.describe()
# Out:
#            Recency    Frequency     Monetary
# count  3913.000000  3913.000000  3913.000000
# mean      0.329587     0.451124     0.558906
# std       0.817281     0.975032     1.589895
# min      -0.436975    -0.250000    -0.504602
# 25%      -0.285714    -0.250000    -0.274189
# 50%       0.000000     0.000000     0.000000
# 75%       0.714286     0.750000     0.725811
# max       2.697479     6.250000    17.862503

# %% [markdown]
# ### 4.2 Determining the optimal number of k
#
# To determine the optimal number of k, we will run a loop over a range of potential k, 2 to 12, and calculate scores for three different methods for every possible k and plotting the results. We employed two different methods to increase the accuracy of the chosen k.
# - *Elbow Method*: The Elbow method runs k-means for a range of k and calculates the sum of squared errors (SSE)for every k. As k increases, that calculated score decreases until it reaches 0 when k equals the n observations in the dataset. Since that would clearly be overfitting of the model, when k = n then every cluster would only include one observation, we are interested in the value of k after which the decrease in SSE becomes linear, the "bend of the elbow" that gives the method its name.
# - *Davis-Bouldin Score*: The score is defined as the average similarity measure of each cluster with its most similar cluster, where similarity is the ratio of within-cluster distances to between-cluster distances. Thus, clusters which are farther apart and less dispersed will result in a better score. The minimum score is zero, where k = n, with lower values indicating better clustering.

# %%
km_scores= []
km_silhouette = []
db_score = []
# for a range of possible k's, we calculate scores and print them out
for i in range(2,12):
    km = KMeans(n_clusters=i, random_state=42).fit(X_scaled)
    preds = km.predict(X_scaled)
    
    print("Score for number of cluster(s) {}: {}".format(i,km.score(X_scaled)))
    km_scores.append(-km.score(X_scaled))

    db = davies_bouldin_score(X_scaled,preds)
    db_score.append(db)
    print("Davies Bouldin index for number of cluster(s) {}: {}/n".format(i,db))
# Out:
# Score for number of cluster(s) 2: -8340.009852298292
# Davies Bouldin index for number of cluster(s) 2: 0.7108080914458749/n
# Score for number of cluster(s) 3: -5804.314982864139
# Davies Bouldin index for number of cluster(s) 3: 0.794625206028294/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# Score for number of cluster(s) 4: -3945.877902139613
# Davies Bouldin index for number of cluster(s) 4: 0.7177902160935834/n
# Score for number of cluster(s) 5: -3013.9445701705213
# Davies Bouldin index for number of cluster(s) 5: 0.7659498520451945/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# Score for number of cluster(s) 6: -2530.861900477973
# Davies Bouldin index for number of cluster(s) 6: 0.8081390173892378/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# Score for number of cluster(s) 7: -2221.899784074076
# Davies Bouldin index for number of cluster(s) 7: 0.8870110450349741/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# Score for number of cluster(s) 8: -2007.191911147407
# Davies Bouldin index for number of cluster(s) 8: 0.9020292934052612/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# Score for number of cluster(s) 9: -1814.07454091329
# Davies Bouldin index for number of cluster(s) 9: 0.8950793832191208/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# Score for number of cluster(s) 10: -1651.5956014811413
# Davies Bouldin index for number of cluster(s) 10: 0.9270801371293261/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# Score for number of cluster(s) 11: -1502.3513942564252
# Davies Bouldin index for number of cluster(s) 11: 0.8930148707226748/n
# C:\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances

# %%
# vidual representation of the elbow method
plt.figure(figsize=(7,4))
plt.title("The elbow method for determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_scores,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("K-means score/ Inertia",fontsize=14)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# The visual examination of the elbow method points to an optimal k between 4 and 6, no clear-cut bend is identifiable.

# %%
# visual representation of the Davies-Bouldin score
plt.figure(figsize=(7,4))
plt.title("The Davis-Bouldin score method \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=db_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Davies-Bouldin score")
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# The Davis-Bouldin score points towards an optimal k of 2 or 4. Given the results of the elbow method, we choose k=4 for the generation of clusters.

# %%
#adding clusters to the dataset
km = KMeans(n_clusters=4, random_state=42).fit(X_scaled)
rfm['cluster'] = km.predict(X_scaled)
X_scaled["cluster"] = km.predict(X_scaled)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# To visually understand the clusters on two variables, we plot a pariplot of all four columns in the target dataset X_scaled.

# %%
sns.pairplot(X_scaled, kind='scatter', hue='cluster')
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %% [markdown]
# That understanding is enhanced by looking at the clusters in a three-dimnensional pane.

# %%
# visualizing the clustering in a 3D-pane
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection='3d')
x_data = X_scaled.Recency
y_data = X_scaled.Frequency
z_data = X_scaled.Monetary
color_data = X_scaled.cluster
scatter_plot = ax.scatter(x_data,y_data,z_data, c= color_data)
legend1 = ax.legend(*scatter_plot.legend_elements(),
                    loc="upper left", title="Generated clusters")
ax.add_artist(legend1)
ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetary')
plt.show()

# %% [markdown]
# ## 5. Results
#
# As we can see in the pane above, four distinct clusters were generated along the three RFM dimensions. We now try to interpret those four clusters in the context of the UK-based online retailer on which this analysis is based.

# %%
# resetting the index to have customer ID as a column and a numerical index again
rfm.reset_index(level=0, inplace=True)

# %%
# analyzing the stats of each cluster to understand differences
for column in rfm.columns:
    if column not in ['cluster', 'Customer ID']: print(rfm[[column, 'cluster']].groupby("cluster").describe())
# Out:
#         Recency
#           count        mean        std    min     25%    50%    75%    max
# cluster
# 0        2285.0   49.293654  37.186742    1.0   18.00   42.0   71.0  179.0
# 1         912.0  247.032895  65.553265  134.0  191.75  239.0  296.0  374.0
# 2         103.0   32.737864  52.602274    1.0    7.50   16.0   32.0  290.0
# 3         613.0   31.905383  40.108646    1.0    8.00   18.0   40.0  327.0
#         Frequency
#             count       mean       std  min   25%   50%   75%   max
# cluster
# 0          2285.0   2.762363  1.731541  1.0   1.0   2.0   4.0  11.0
# 1           912.0   1.501096  0.935927  1.0   1.0   1.0   2.0   8.0
# 2           103.0  15.407767  6.339167  1.0  12.0  15.0  19.5  27.0
# 3           613.0   9.166395  3.823950  1.0   7.0   8.0  11.0  27.0
#         Monetary                                                          \
#            count          mean          std      min        25%      50%
# cluster
# 0         2285.0    790.870136   574.247498    10.95   328.1300   631.17
# 1          912.0    394.168424   394.184046     2.95   155.4125   281.78
# 2          103.0  10555.480194  3809.570071  6174.47  7745.5450  9530.08
# 3          613.0   3474.109439  1318.254985  1094.39  2475.3200  3145.86
#
#
#                 75%        max
# cluster
# 0         1157.3000   3138.040
# 1          465.4475   3537.821
# 2        11366.4100  23712.310
# 3         4266.5500   7493.770

# %% [markdown]
# Looking at the descriptive data of the clusters above, we can distinguish clear characteristics on every customer segment:
#
# - *Cluster 0*: Cluster 0 encompasses the largest cluster of the four with 2285 of the 3913 customers belonging to this cluster. Defining features of this cluster are recent purchases for low to decent total amounts of money. They are most likely new customers that did not have time to complete re-purchases as the retailer. Therefore, they might represent an interesting group to develop in the future as they represent a large portion of the customer base. We therefore call them "question marks" going forward.
# - *Cluster 1": Cluster 1 clearly represents the least interesting customer group. On average, they represent a group that shopped the least in total, spent the least amount of money, and made their purchases a long time ago. Therefore, the retailer should spent the least amount of effort on this group, although some customers might be reactivatable through targeted CRM activities. We call them "Dorments"going forward.
# - *Cluster 2*: This customer group represents the absolute power users of the retailer. On average, they are active, spend the most, and buy more than other groups. The defining feature is clearly the monetary amount spent though. It is likely that these customers present larger commercial buyers. We call those the "stars" going forward.
# - *Cluster 3*: Cluster three encompasses active customers that spend reasonable amounts of money on the retailer's platform. They present the opportunity to be developed into stars in the future through clever recommendations and cross-selling initiatives. Therefore, we call them "Prospects" going forward.
